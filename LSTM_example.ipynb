# %% [markdown]
# <a href="https://colab.research.google.com/github/iakovkh/mypython/blob/main/LSTM_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

def read_excel_file(file_path):
    # Read the Excel file into a DataFrame
    data = pd.read_excel(file_path)
    return data

def plot_close_column(data):
    # Check if 'close' column exists in the data
    if 'Close' in data.columns:
        plt.figure(figsize=(10, 6))
        plt.plot(data['Close'], label='Close Price')
        plt.xlabel('Index')
        plt.ylabel('Close Price')
        plt.title('Close Price Over Time')
        plt.legend()
        plt.grid(True)
        plt.show()
    else:
        print("The 'close' column does not exist in the data.")

# Example usage
file_path = '/content/SPY_sample.xlsx'
data = read_excel_file(file_path)

# Print the data to verify
#print(data)

# Plot the 'close' column
plot_close_column(data)
